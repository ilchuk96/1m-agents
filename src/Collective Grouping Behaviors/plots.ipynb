# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
log0 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0', sep='\t', header=None)
log000005 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_5e-05', sep='\t', header=None)
log00001 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0.0001', sep='\t', header=None)
log000015 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0.00015', sep='\t', header=None)
log00002 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0.0002', sep='\t', header=None)
log00003 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0.0003', sep='\t', header=None)
log00004 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0.0004', sep='\t', header=None)
log00005 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0.0005', sep='\t', header=None)
log0001 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0.001', sep='\t', header=None)
log0002 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0.002', sep='\t', header=None)
log0005 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0.005', sep='\t', header=None)
log001 = pd.read_csv('Collective_Grouping_Behaviors_fine_size_0.001', sep='\t', header=None)

pig_num0 = log0[5].values
pig_num000005 = log000005[5].values
pig_num00001 = log00001[5].values
pig_num000015 = log000015[5].values
pig_num00002 = log00002[5].values
pig_num00003 = log00003[5].values
pig_num00004 = log00004[5].values
pig_num00005 = log00005[5].values
pig_num0001 = log0001[5].values
pig_num0002 = log0002[5].values
pig_num0005 = log0005[5].values
pig_num001 = log001[5].values

agent_num0 = log0[13].values
agent_num000005 = log000005[13].values
agent_num00001 = log00001[13].values
agent_num000015 = log000015[13].values
agent_num00002 = log00002[13].values
agent_num00003 = log00003[13].values
agent_num00004 = log00004[13].values
agent_num00005 = log00005[13].values
agent_num0001 = log0001[13].values
agent_num0002 = log0002[13].values
agent_num0005 = log0005[13].values
agent_num001 = log001[13].values

time = range(50*150)
round = range(50)

# %%
plt.plot(round, pig_num0[149::150], label = u'0.0')
plt.plot(round, pig_num000005[149::150], label = u'0.00005')
plt.plot(round, pig_num00001[149::150], label = u'0.0001')
plt.plot(round, pig_num000015[149::150], label = u'0.00015')
plt.plot(round, pig_num00002[149::150], label = u'0.0002')
plt.plot(round, pig_num00003[149::150], label = u'0.0003')
plt.plot(round, pig_num00004[149::150], label = u'0.0004')
plt.plot(round, pig_num00005[149::150], label = u'0.0005')
plt.plot(round, pig_num0001[149::150], label = u'0.001')
plt.plot(round, pig_num0002[149::150], label = u'0.002')
plt.plot(round, pig_num0005[149::150], label = u'0.005')
#plt.plot(round, pig_num001[149::150], label = u'0.01')
plt.xlabel(u'Раунд')
plt.ylabel(u'Количество свиней')
plt.legend()
plt.show()

# %%
plt.plot(round[:10], pig_num0[149:1500:150], label = u'0.0')
plt.plot(round[:10], pig_num000005[149:1500:150], label = u'0.00005')
plt.plot(round[:10], pig_num00001[149:1500:150], label = u'0.0001')
plt.plot(round[:10], pig_num000015[149:1500:150], label = u'0.00015')
plt.plot(round[:10], pig_num00002[149:1500:150], label = u'0.0002')
plt.plot(round[:10], pig_num00003[149:1500:150], label = u'0.0003')
plt.plot(round[:10], pig_num00004[149:1500:150], label = u'0.0004')
plt.plot(round[:10], pig_num00005[149:1500:150], label = u'0.0005')
plt.plot(round[:10], pig_num0001[149:1500:150], label = u'0.001')
plt.plot(round[:10], pig_num0002[149:1500:150], label = u'0.002')
plt.plot(round[:10], pig_num0005[149:1500:150], label = u'0.005')
#plt.plot(round[:10], pig_num001[149:1500:150], label = u'0.01')
plt.xlabel(u'Раунд')
plt.ylabel(u'Количество свиней')
plt.legend()
plt.show()

# %%
plt.plot(round, agent_num0[149::150], label = u'0.0')
plt.plot(round, agent_num000005[149::150], label = u'0.00005')
plt.plot(round, agent_num00001[149::150], label = u'0.0001')
plt.plot(round, agent_num000015[149::150], label = u'0.00015')
plt.plot(round, agent_num00002[149::150], label = u'0.0002')
plt.plot(round, agent_num00003[149::150], label = u'0.0003')
plt.plot(round, agent_num00004[149::150], label = u'0.0004')
plt.plot(round, agent_num00005[149::150], label = u'0.0005')
plt.plot(round, agent_num0001[149::150], label = u'0.001')
plt.plot(round, agent_num0002[149::150], label = u'0.002')
plt.plot(round, agent_num0005[149::150], label = u'0.005')
#plt.plot(round, agent_num001[149::150], label = u'0.01')
plt.xlabel(u'Раунд')
plt.ylabel(u'Количество агентов')
plt.legend()
plt.show()

# %%
plt.plot(round[:10], agent_num0[149:1500:150], label = u'0.0')
plt.plot(round[:10], agent_num000005[149:1500:150], label = u'0.00005')
plt.plot(round[:10], agent_num00001[149:1500:150], label = u'0.0001')
plt.plot(round[:10], agent_num000015[149:1500:150], label = u'0.00015')
plt.plot(round[:10], agent_num00002[149:1500:150], label = u'0.0002')
plt.plot(round[:10], agent_num00003[149:1500:150], label = u'0.0003')
plt.plot(round[:10], agent_num00004[149:1500:150], label = u'0.0004')
plt.plot(round[:10], agent_num00005[149:1500:150], label = u'0.0005')
plt.plot(round[:10], agent_num0001[149:1500:150], label = u'0.001')
plt.plot(round[:10], agent_num0002[149:1500:150], label = u'0.002')
plt.plot(round[:10], agent_num0005[149:1500:150], label = u'0.005')
#plt.plot(round[:10], agent_num001[149:1500:150], label = u'0.01')
plt.xlabel(u'Раунд')
plt.ylabel(u'Количество агентов')
plt.legend()
plt.show()

# %%
aver10_pig_num0 = [sum(pig_num0[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]
aver10_pig_num01 = [sum(pig_num01[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]
aver10_pig_num005 = [sum(pig_num005[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]
aver10_pig_num0025 = [sum(pig_num0025[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]
aver10_pig_num00125 = [sum(pig_num00125[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]
aver10_pig_num0001 = [sum(pig_num0001[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]

aver10_agent_num0 = [sum(agent_num0[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]
aver10_agent_num01 = [sum(agent_num01[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]
aver10_agent_num005 = [sum(agent_num005[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]
aver10_agent_num0025 = [sum(agent_num0025[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]
aver10_agent_num00125 = [sum(agent_num00125[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]
aver10_agent_num0001 = [sum(agent_num0001[10*i*150+149:10*(i+1)*150:150]) / 10 for i in range(10)]

time10 = range(10)

# %%
plt.plot(time10, aver10_pig_num0, label = u'0.0')
plt.plot(time10, aver10_pig_num01, label = u'0.01')
plt.plot(time10, aver10_pig_num005, label = u'0.005')
plt.plot(time10, aver10_pig_num0025, label = u'0.0025')
plt.plot(time10, aver10_pig_num00125, label = u'0.00125')
plt.plot(time10, aver10_pig_num0001, label = u'0.0001')
plt.xlabel(u'Раунд 10x')
plt.ylabel(u'Среднее количество свиней')
plt.legend()
plt.show()

# %%
plt.plot(time10, aver10_agent_num0, label = u'0.0')
plt.plot(time10, aver10_agent_num01, label = u'0.01')
plt.plot(time10, aver10_agent_num005, label = u'0.005')
plt.plot(time10, aver10_agent_num0025, label = u'0.0025')
plt.plot(time10, aver10_agent_num00125, label = u'0.00125')
plt.plot(time10, aver10_agent_num0001, label = u'0.0001')
plt.xlabel(u'Раунд 10x')
plt.ylabel(u'Среднее количество агентов')
plt.legend()
plt.show()
